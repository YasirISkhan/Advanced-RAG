# %%
# !pip install langchain chromadb tiktoken pypdf langchain_openai langchain-community
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.3/23.3 MB 72.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 382.9/382.9 kB 24.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.7/123.7 kB 9.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 75.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 20.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 111.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 54.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 565.9/565.9 kB 28.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.2/19.2 MB 81.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.2/137.2 kB 11.2 MB/s eta 0:00:00
# ...

# %%
# !pip install -qU langchain langchain-pinecone langchain-openai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.0/147.0 kB 10.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 248.9/248.9 kB 19.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.7/16.7 MB 84.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.6/587.6 kB 33.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.3/259.3 kB 17.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 3.8 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.5.2 which is incompatible.
# google-adk 2.4.0 requires opentelemetry-api<=1.42.1,>=1.39, but you have opentelemetry-api 1.44.0 which is incompatible.
# ...

# %%
# !pip install langchain_huggingface

# %%
# !pip install -U sentence-transformers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.3/611.3 kB 23.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: sentence-transformers
#     Found existing installation: sentence-transformers 5.6.0
#     Uninstalling sentence-transformers-5.6.0:
#       Successfully uninstalled sentence-transformers-5.6.0
# ...

# %%
from langchain_huggingface import HuggingFaceEmbeddings
from pinecone import Pinecone, ServerlessSpec

import os

os.environ["PINECONE_API_KEY"] = "pcsk_3XkxeS_BEMbkgHDTx9QbC8arBexbXrWpQZDyc9BUA2XT8qA87FTuxRtrryzwGMAGwww2N9"

pc = Pinecone(api_key=os.environ["PINECONE_API_KEY"])
index_name = "psl-players"

pc.create_index(
    name=index_name,
    dimension=384,
    metric="cosine",
    spec=ServerlessSpec(
        cloud="aws",
        region="us-east-1"
    )
)
# Out:
# ---------------------------------------------------------------------------
# PineconeApiException                      Traceback (most recent call last)
# /tmp/ipykernel_10330/785320404.py in <cell line: 0>()
#       9 index_name = "psl-players"
#      10
# ---> 11 pc.create_index(
#      12     name=index_name,
#      13     dimension=384,
#
# /usr/local/lib/python3.12/dist-packages/pinecone/pinecone.py in create_index(self, name, spec, dimension, metric, timeout, deletion_protection, vector_type, tags)
#     332         tags: Optional[Dict[str, str]] = None,
#     333     ) -> "IndexModel":
# --> 334         return self.db.index.create(
#     335             name=name,
#     336             spec=spec,
#
# /usr/local/lib/python3.12/dist-packages/pinecone/utils/require_kwargs.py in wrapper(*args, **kwargs)
#      12                 f"Please use {func.__name__}({', '.join(f'{name}=value' for name in param_names)})"
#      13             )
# ...

# %%
from langchain_pinecone import PineconeVectorStore

embedding_model = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

pinecone_vector_store = PineconeVectorStore(
    index_name=index_name,
    embedding=embedding_model
)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B / 90.9MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# ...

# %%
# Create LangChain documents for PSL players
from langchain_core.documents import Document
doc1 = Document(
    page_content="Babar Azam is one of the most successful and consistent batsmen in PSL history. Known for his aggressive batting style and fitness, he has led the Peshawar Zalmi in multiple seasons.",
    metadata={"team": "Peshawar Zalmi"}
)
doc2 = Document(
    page_content="Shaheen Afridi is the most successful captain in PSL history, leading Lahore Qalandars to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
    metadata={"team": "Lahore Qalandars"}
)
doc3 = Document(
    page_content="Mohammad Rizwan, famously known as Captain Cool, has led Multan Sultans to multiple PSL titles. His finishing skills, wicketkeeping, and leadership are legendary.",
    metadata={"team": "Multan Sultans"}
)
doc4 = Document(
    page_content="Haris Rauf is considered one of the best fast bowlers in T20 cricket. Playing for Islamabad United, he is known for his yorkers and death-over expertise.",
    metadata={"team": "Islamabad United"}
)
doc5 = Document(
    page_content="Shadab Khan is a dynamic all-rounder who contributes with both bat and ball. Representing Quetta Gladiators, his quick fielding and match-winning performances make him a key player.",
    metadata={"team": "Quetta Gladiators"}
)

# %%
docs = [doc1, doc2, doc3, doc4, doc5]

# %%
pinecone_vector_store.add_documents(docs)
# Out:
# ['1194d5c3-fb1e-4f8a-b609-4211be1ee2de',
#  '83c9dc09-2002-416a-a638-07ddfae55159',
#  '68917f88-36a4-48a2-8efe-e13f6f2807bd',
#  'a889266d-e8bc-4d8d-ada5-36c96b9fd276',
#  '68ea3288-b933-457e-b5da-0c8dc2a16432']

# %%
for doc in docs:
    print("Text:", doc.page_content)
    print("Metadata:", doc.metadata)
    print()
# Out:
# Text: Babar Azam is one of the most successful and consistent batsmen in PSL history. Known for his aggressive batting style and fitness, he has led the Peshawar Zalmi in multiple seasons.
# Metadata: {'team': 'Peshawar Zalmi', 'text': 'Babar Azam is one of the most successful and consistent batsmen in PSL history. Known for his aggressive batting style and fitness, he has led the Peshawar Zalmi in multiple seasons.'}
#
# Text: Shaheen Afridi is the most successful captain in PSL history, leading Lahore Qalandars to five titles. He's known for his calm demeanor and ability to play big innings under pressure.
# Metadata: {'team': 'Lahore Qalandars', 'text': "Shaheen Afridi is the most successful captain in PSL history, leading Lahore Qalandars to five titles. He's known for his calm demeanor and ability to play big innings under pressure."}
#
# ...

# %%
results = pinecone_vector_store.similarity_search(
    "Who is a fast bowler?",
    k=2
)

for doc in results:
    print(doc.page_content)
    print(doc.metadata)
    print()
# Out:
# Haris Rauf is considered one of the best fast bowlers in T20 cricket. Playing for Islamabad United, he is known for his yorkers and death-over expertise.
# {'team': 'Islamabad United'}
#
# Shadab Khan is a dynamic all-rounder who contributes with both bat and ball. Representing Quetta Gladiators, his quick fielding and match-winning performances make him a key player.
# {'team': 'Quetta Gladiators'}

# %%
# search with similarity score
pinecone_vector_store.similarity_search_with_score(
    query = 'Who among these are a bowler?',
    k=2
)
# Out:
# [(Document(id='a889266d-e8bc-4d8d-ada5-36c96b9fd276', metadata={'team': 'Islamabad United'}, page_content='Haris Rauf is considered one of the best fast bowlers in T20 cricket. Playing for Islamabad United, he is known for his yorkers and death-over expertise.'),
#   0.544272482),
#  (Document(id='83c9dc09-2002-416a-a638-07ddfae55159', metadata={'team': 'Lahore Qalandars'}, page_content="Shaheen Afridi is the most successful captain in PSL history, leading Lahore Qalandars to five titles. He's known for his calm demeanor and ability to play big innings under pressure."),
#   0.390936881)]

# %%
# meta-data filtering

pinecone_vector_store.similarity_search_with_score(
    query = '',
    filter={'team': 'Multan Sultans'}
)
# Out:
# [(Document(id='68917f88-36a4-48a2-8efe-e13f6f2807bd', metadata={'team': 'Multan Sultans'}, page_content='Mohammad Rizwan, famously known as Captain Cool, has led Multan Sultans to multiple PSL titles. His finishing skills, wicketkeeping, and leadership are legendary.'),
#   0.0555582047)]

# %%
# update documents
updated_doc1 = Document(
    page_content="Muhammad Nawaz, the former captain of Quetta Gladiators, is renowned for his effective all-round performances and consistent contributions. He is known for his ability to contribute with both bat and ball in the Pakistan Super League. His versatility and composure have made him a valuable player in T20 cricket. His ability to perform under pressure and contribute in crucial moments has made him one of the dependable all-rounders in the league.",
    metadata={"team": "Quetta Gladiators"}
)

pinecone_vector_store.add_documents(
    [updated_doc1],
    ids=["1194d5c3-fb1e-4f8a-b609-4211be1ee2de"]
)
# Out:
# ['1194d5c3-fb1e-4f8a-b609-4211be1ee2de']

# %%
pinecone_vector_store.delete(ids=['76644e82-b2f4-4981-926d-195a20ced2db'])
