# %%
# !pip install -U langchain-community langchain-openai tiktoken
# Out:
# Collecting langchain-community
#   Downloading langchain_community-0.4.2-py3-none-any.whl.metadata (3.4 kB)
# Collecting langchain-openai
#   Downloading langchain_openai-1.5.1-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.12/dist-packages (0.13.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (3.14.1)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community)
#   Downloading httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# Collecting langchain-classic<2.0.0,>=1.0.7 (from langchain-community)
#   Downloading langchain_classic-1.0.8-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (1.4.9)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (0.10.2)
# Requirement already satisfied: numpy>=1.26.2 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.0.2)
# Collecting pydantic-settings<3.0.0,>=2.10.1 (from langchain-community)
#   Downloading pydantic_settings-2.15.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (6.0.3)
# Collecting requests<3.0.0,>=2.32.5 (from langchain-community)
#   Downloading requests-2.34.2-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.0.51)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (9.1.4)
# Requirement already satisfied: certifi>=2024.6.2 in /usr/local/lib/python3.12/dist-packages (from langchain-openai) (2026.6.17)
# Collecting langchain-core<2.0.0,>=1.4.0 (from langchain-community)
#   Downloading langchain_core-1.5.5-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: openai<4.0.0,>=2.45.0 in /usr/local/lib/python3.12/dist-packages (from langchain-openai) (2.45.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from tiktoken) (2025.11.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.5.2)
# Requirement already satisfied: typing_extensions>=4.4 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.16.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.24.2)
# Collecting langchain-text-splitters<2.0.0,>=1.1.2 (from langchain-classic<2.0.0,>=1.0.7->langchain-community)
#   Downloading langchain_text_splitters-1.1.2-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (2.13.4)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (0.0.18)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (26.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (0.17.0)
# Requirement already satisfied: anyio>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (4.14.2)
# Requirement already satisfied: distro>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.9.0)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.3.1)
# Requirement already satisfied: websockets>=15.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.8.1)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai<4.0.0,>=2.45.0->langchain-openai) (0.16.0)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai<4.0.0,>=2.45.0->langchain-openai) (4.67.3)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.5.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-community) (3.5.3)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.4.0->langchain-community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.4.0->langchain-community) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.0->langchain-community) (3.1.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain-community) (2.46.4)
# Downloading langchain_community-0.4.2-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 26.6 MB/s eta 0:00:00
# Downloading langchain_openai-1.5.1-py3-none-any.whl (123 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.7/123.7 kB 8.4 MB/s eta 0:00:00
# Downloading httpx_sse-0.4.3-py3-none-any.whl (9.0 kB)
# Downloading langchain_classic-1.0.8-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 42.3 MB/s eta 0:00:00
# Downloading langchain_core-1.5.5-py3-none-any.whl (565 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 565.9/565.9 kB 25.8 MB/s eta 0:00:00
# Downloading pydantic_settings-2.15.0-py3-none-any.whl (69 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.4/69.4 kB 4.6 MB/s eta 0:00:00
# Downloading requests-2.34.2-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 5.1 MB/s eta 0:00:00
# Downloading langchain_text_splitters-1.1.2-py3-none-any.whl (35 kB)
# Installing collected packages: requests, httpx-sse, pydantic-settings, langchain-core, langchain-text-splitters, langchain-openai, langchain-classic, langchain-community
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.4.9
#     Uninstalling langchain-core-1.4.9:
#       Successfully uninstalled langchain-core-1.4.9
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.
# Successfully installed httpx-sse-0.4.3 langchain-classic-1.0.8 langchain-community-0.4.2 langchain-core-1.5.5 langchain-openai-1.5.1 langchain-text-splitters-1.1.2 pydantic-settings-2.15.0 requests-2.34.2

# %%
# !pip install faiss-cpu
# Out:
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.15.0-cp310-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (7.8 kB)
# Requirement already satisfied: numpy>=1.25 in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (26.2)
# Downloading faiss_cpu-1.15.0-cp310-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (18.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.8/18.8 MB 69.3 MB/s eta 0:00:00
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.15.0

# %%
# !pip install langchain_huggingface -U sentence-transformers
# Out:
# Collecting langchain_huggingface
#   Downloading langchain_huggingface-1.2.2-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.12/dist-packages (5.6.0)
# Collecting sentence-transformers
#   Downloading sentence_transformers-5.7.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: huggingface-hub<2.0.0,>=0.33.4 in /usr/local/lib/python3.12/dist-packages (from langchain_huggingface) (1.23.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.31 in /usr/local/lib/python3.12/dist-packages (from langchain_huggingface) (1.5.5)
# Requirement already satisfied: tokenizers<1.0.0,>=0.19.1 in /usr/local/lib/python3.12/dist-packages (from langchain_huggingface) (0.22.2)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (5.13.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (2.11.0+cpu)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (2.0.2)
# Requirement already satisfied: scikit-learn>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (1.16.3)
# Requirement already satisfied: typing_extensions>=4.5.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (4.16.0)
# Requirement already satisfied: tqdm>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (4.67.3)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (8.4.2)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (3.29.7)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (1.5.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (6.0.3)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (0.10.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (2.13.4)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (9.1.4)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (0.17.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.22.0->sentence-transformers) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.22.0->sentence-transformers) (3.6.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: regex>=2025.10.22 in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2025.11.3)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.26.8)
# Requirement already satisfied: safetensors>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.8.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (4.14.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (3.18)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (3.1.1)
# Requirement already satisfied: distro>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (1.9.0)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (1.3.1)
# Requirement already satisfied: websockets>=15.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (3.8.1)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (0.4.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (0.0.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (2.5.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (0.1.2)
# Downloading langchain_huggingface-1.2.2-py3-none-any.whl (31 kB)
# Downloading sentence_transformers-5.7.0-py3-none-any.whl (611 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.3/611.3 kB 8.8 MB/s eta 0:00:00
# Installing collected packages: langchain_huggingface, sentence-transformers
#   Attempting uninstall: sentence-transformers
#     Found existing installation: sentence-transformers 5.6.0
#     Uninstalling sentence-transformers-5.6.0:
#       Successfully uninstalled sentence-transformers-5.6.0
# Successfully installed langchain_huggingface-1.2.2 sentence-transformers-5.7.0

# %%
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS

embedding_model = HuggingFaceEmbeddings(
    model_name = 'sentence-transformers/all-MiniLM-L6-v2'
)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B / 90.9MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
# Create LangChain documents for PSL players
from langchain_core.documents import Document
doc1 = Document(
    page_content="Babar Azam is one of the most successful and consistent batsmen in PSL history. Known for his aggressive batting style and fitness, he has led the Peshawar Zalmi in multiple seasons.",
    metadata={"team": "Peshawar Zalmi"}
)
doc2 = Document(
    page_content="Shaheen Afridi is the most successful captain in PSL history, leading Lahore Qalandars to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
    metadata={"team": "Lahore Qalandars"}
)
doc3 = Document(
    page_content="Mohammad Rizwan, famously known as Captain Cool, has led Multan Sultans to multiple PSL titles. His finishing skills, wicketkeeping, and leadership are legendary.",
    metadata={"team": "Multan Sultans"}
)
doc4 = Document(
    page_content="Haris Rauf is considered one of the best fast bowlers in T20 cricket. Playing for Islamabad United, he is known for his yorkers and death-over expertise.",
    metadata={"team": "Islamabad United"}
)
doc5 = Document(
    page_content="Shadab Khan is a dynamic all-rounder who contributes with both bat and ball. Representing Quetta Gladiators, his quick fielding and match-winning performances make him a key player.",
    metadata={"team": "Quetta Gladiators"}
)

# %%
docs = [doc1, doc2, doc3, doc4, doc5]

# %%
faiss_vector_store = FAISS.from_documents(
    docs,
    embedding=embedding_model
)

# %%
faiss_vector_store

# %%
faiss_vector_store.add_documents(docs)
# Out:
# ['cd583a2d-1341-4878-bf07-05d21a6e8b09',
#  'd3e0b9dd-d6a2-426c-b6dd-29d9b549b7d7',
#  '5f3b3002-0adc-4c84-b00a-90587283e1df',
#  '85aae013-ede3-4903-a8cb-9f54f75da8ea',
#  'becb8d91-4e9a-48c8-b687-adbb4f2aa1ba']

# %%
for doc_id, doc in faiss_vector_store.docstore._dict.items():
    print("ID:", doc_id)
    print("Content:", doc.page_content)
    print("Metadata:", doc.metadata)
    print("-" * 50)
# Out:
# ID: 7974f9a7-021f-44cc-a46f-b2f8817b3004
# Content: Babar Azam is one of the most successful and consistent batsmen in PSL history. Known for his aggressive batting style and fitness, he has led the Peshawar Zalmi in multiple seasons.
# Metadata: {'team': 'Peshawar Zalmi'}
# --------------------------------------------------
# ID: 37f75dda-fd5b-46cb-9932-4dee310d2b87
# Content: Shaheen Afridi is the most successful captain in PSL history, leading Lahore Qalandars to five titles. He's known for his calm demeanor and ability to play big innings under pressure.
# Metadata: {'team': 'Lahore Qalandars'}
# --------------------------------------------------
# ID: 846deab8-07cb-48f5-bbab-a4d8b65ffa5d
# Content: Mohammad Rizwan, famously known as Captain Cool, has led Multan Sultans to multiple PSL titles. His finishing skills, wicketkeeping, and leadership are legendary.
# Metadata: {'team': 'Multan Sultans'}
# --------------------------------------------------
# ID: 9fa12bf8-04e7-444b-a11b-eaf6dadd510a
# Content: Haris Rauf is considered one of the best fast bowlers in T20 cricket. Playing for Islamabad United, he is known for his yorkers and death-over expertise.
# Metadata: {'team': 'Islamabad United'}
# --------------------------------------------------
# ID: 3847019e-9236-413c-ad26-3ba72ff5babd
# Content: Shadab Khan is a dynamic all-rounder who contributes with both bat and ball. Representing Quetta Gladiators, his quick fielding and match-winning performances make him a key player.
# Metadata: {'team': 'Quetta Gladiators'}
# --------------------------------------------------
# ID: cd583a2d-1341-4878-bf07-05d21a6e8b09
# Content: Babar Azam is one of the most successful and consistent batsmen in PSL history. Known for his aggressive batting style and fitness, he has led the Peshawar Zalmi in multiple seasons.
# Metadata: {'team': 'Peshawar Zalmi'}
# --------------------------------------------------
# ID: d3e0b9dd-d6a2-426c-b6dd-29d9b549b7d7
# Content: Shaheen Afridi is the most successful captain in PSL history, leading Lahore Qalandars to five titles. He's known for his calm demeanor and ability to play big innings under pressure.
# Metadata: {'team': 'Lahore Qalandars'}
# --------------------------------------------------
# ID: 5f3b3002-0adc-4c84-b00a-90587283e1df
# Content: Mohammad Rizwan, famously known as Captain Cool, has led Multan Sultans to multiple PSL titles. His finishing skills, wicketkeeping, and leadership are legendary.
# Metadata: {'team': 'Multan Sultans'}
# --------------------------------------------------
# ID: 85aae013-ede3-4903-a8cb-9f54f75da8ea
# Content: Haris Rauf is considered one of the best fast bowlers in T20 cricket. Playing for Islamabad United, he is known for his yorkers and death-over expertise.
# Metadata: {'team': 'Islamabad United'}
# --------------------------------------------------
# ID: becb8d91-4e9a-48c8-b687-adbb4f2aa1ba
# Content: Shadab Khan is a dynamic all-rounder who contributes with both bat and ball. Representing Quetta Gladiators, his quick fielding and match-winning performances make him a key player.
# Metadata: {'team': 'Quetta Gladiators'}
# --------------------------------------------------

# %%
faiss_vector_store.similarity_search(
    query='Who among these are a bowler?',
    k=2
)
# Out:
# [Document(id='9fa12bf8-04e7-444b-a11b-eaf6dadd510a', metadata={'team': 'Islamabad United'}, page_content='Haris Rauf is considered one of the best fast bowlers in T20 cricket. Playing for Islamabad United, he is known for his yorkers and death-over expertise.'),
#  Document(id='85aae013-ede3-4903-a8cb-9f54f75da8ea', metadata={'team': 'Islamabad United'}, page_content='Haris Rauf is considered one of the best fast bowlers in T20 cricket. Playing for Islamabad United, he is known for his yorkers and death-over expertise.')]

# %%
faiss_vector_store.similarity_search_with_score(
    query = 'Who among these are a bowler?',
    k=5
)
# Out:
# [(Document(id='9fa12bf8-04e7-444b-a11b-eaf6dadd510a', metadata={'team': 'Islamabad United'}, page_content='Haris Rauf is considered one of the best fast bowlers in T20 cricket. Playing for Islamabad United, he is known for his yorkers and death-over expertise.'),
#   np.float32(0.9125006)),
#  (Document(id='85aae013-ede3-4903-a8cb-9f54f75da8ea', metadata={'team': 'Islamabad United'}, page_content='Haris Rauf is considered one of the best fast bowlers in T20 cricket. Playing for Islamabad United, he is known for his yorkers and death-over expertise.'),
#   np.float32(0.9125006)),
#  (Document(id='37f75dda-fd5b-46cb-9932-4dee310d2b87', metadata={'team': 'Lahore Qalandars'}, page_content="Shaheen Afridi is the most successful captain in PSL history, leading Lahore Qalandars to five titles. He's known for his calm demeanor and ability to play big innings under pressure."),
#   np.float32(1.2189676)),
#  (Document(id='d3e0b9dd-d6a2-426c-b6dd-29d9b549b7d7', metadata={'team': 'Lahore Qalandars'}, page_content="Shaheen Afridi is the most successful captain in PSL history, leading Lahore Qalandars to five titles. He's known for his calm demeanor and ability to play big innings under pressure."),
#   np.float32(1.2189676)),
#  (Document(id='3847019e-9236-413c-ad26-3ba72ff5babd', metadata={'team': 'Quetta Gladiators'}, page_content='Shadab Khan is a dynamic all-rounder who contributes with both bat and ball. Representing Quetta Gladiators, his quick fielding and match-winning performances make him a key player.'),
#   np.float32(1.2245805))]

# %%
faiss_vector_store.similarity_search_with_score(
    query="",
    filter={'team': 'Multan Sultans'}
)
# Out:
# [(Document(id='846deab8-07cb-48f5-bbab-a4d8b65ffa5d', metadata={'team': 'Multan Sultans'}, page_content='Mohammad Rizwan, famously known as Captain Cool, has led Multan Sultans to multiple PSL titles. His finishing skills, wicketkeeping, and leadership are legendary.'),
#   np.float32(1.8880968)),
#  (Document(id='5f3b3002-0adc-4c84-b00a-90587283e1df', metadata={'team': 'Multan Sultans'}, page_content='Mohammad Rizwan, famously known as Captain Cool, has led Multan Sultans to multiple PSL titles. His finishing skills, wicketkeeping, and leadership are legendary.'),
#   np.float32(1.8880968))]

# %%
# update documents
updated_doc1 = Document(
    page_content="Muhammad Nawaz, the former captain of Quetta Gladiators, is renowned for his effective all-round performances and consistent contributions. He is known for his ability to contribute with both bat and ball in the Pakistan Super League. His versatility and composure have made him a valuable player in T20 cricket. His ability to perform under pressure and contribute in crucial moments has made him one of the dependable all-rounders in the league.",
    metadata={"team": "Quetta Gladiators"}
)

faiss_vector_store.add_documents(updated_doc1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_417/1021732643.py in <cell line: 0>()
#       5 )
#       6
# ----> 7 faiss_vector_store.add_documents(updated_doc1)
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/vectorstores/base.py in add_documents(self, documents, **kwargs)
#     247         if type(self).add_texts != VectorStore.add_texts:
#     248             if "ids" not in kwargs:
# --> 249                 ids = [doc.id for doc in documents]
#     250
#     251                 # If there's at least one valid ID, we'll assume that IDs
#
# AttributeError: 'tuple' object has no attribute 'id'

# %%
# delete document
faiss_vector_store.delete(ids=['846deab8-07cb-48f5-bbab-a4d8b65ffa5d'])
# Out:
# True
